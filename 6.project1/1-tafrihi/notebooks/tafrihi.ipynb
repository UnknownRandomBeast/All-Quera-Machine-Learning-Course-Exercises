# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# تفریحی
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در این تمرین قصد داریم به پیشبینی دلیل سفر کاربران بپردازیم. برخی از کاربران مستربلیط به دلیل کاری و برخی دیگر به دلایل تفریحی به سفر می‌روند. به منظور شخصی‌سازی بیشتر و دقیق‌تر، مستربلیط قصد دارد بداند هر بلیط به چه دلیلی رزرو می‌شود.
#     <br>
#     حال از داده‌هایی که در اختیارتان قرار گرفته است استفاده کنید و مدلی آموزش دهید که تفریحی یا کاری بودن سفر را تشخیص دهد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد کنید.
# </font>
# </p>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معرفی مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# مجموعه داده آموزشی شامل ۱۰۱۰۱۷ سطر است که در جدول زیر، توضیحات هر ستون آمده است.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |Created|زمان ثبت بلیط|
# |CancelTime|زمانی که مسافر بلیط را کنسل کرده است|
# |DepartureTime|زمان حرکت|
# |BillID|شناسه خرید|
# |TicketID|شناسه بلیط|
# |ReserveStatus|وضعیت پرداخت مشتری|
# |UserID|شناسه کاربری|
# |Male|آیا بلیط متعلق به زن است یا مرد|
# |Price|قیمت بلیط بدون تخفیف|
# |CouponDiscount|تخفیفی که شخص روی بلیط اعمال کرده است|
# |From|مبدا سفر|
# |To|مقصد سفر|
# |Domestic|آیا سفر، داخلی است یا خارجی|
# |VehicleType|جزئیات وسیله نقلیه را مشخص می‌کند|
# |VehicleClass|آیا وسیله نقلیه، فرست‌کلس است یا نه|
# |Vehicle|نوع وسیله نقلیه|
# |Cancel|آیا بلیط کنسل شده‌است یا نه|
# |HashPassportNumber_p|هش‌شده شماره پاسپورت|
# |HashEmail|هش‌شده ایمیل|
# |BuyerMobile|هش‌شده شماره موبایل|
# |NationalCode|هش‌شده شماره‌ملی|
# |TripReason|دلیل سفر|
#
# </font>
# </div>
# </center>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     مجموعه داده آزمایش نیز مانند مجموعه آموزش است با این تفاوت که ستون <code>TripReason</code> که متغیر هدف مسئله است را در خود ندارد. مجموعه داده آزمایش ۴۳۲۹۳ سطر دارد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# خواندن مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در ابتدا نیاز است فایل‌های مجموعه‌داده را بخوانید. نمونه‌های آموزشی در فایل <code>train.csv</code> و نمونه‌های آزمون که باید دسته‌ی آن‌ها را پیش‌بینی کنید در فایل <code>test.csv</code> ذخیره شده‌اند. اگر لازم دانستید می‌توانید به دلخواه خود بخشی از دادگان آموزشی را به عنوان دادگان اعتبارسنجی نیز جدا کنید.
# </font>
# </p>

# %%
train_data = pd.read_csv('../data/train_data.csv')
train_data
# Out:
#                         Created CancelTime        DepartureTime    BillID  \
# 0       2022-10-23 09:38:49.110        NaN  2022-11-02 23:59:00  39710203
# 1       2022-08-15 14:51:43.160        NaN  2022-08-18 04:15:00  38689463
# 2       2022-09-20 17:25:27.250        NaN  2022-09-21 11:00:00  39245173
# 3       2022-06-25 11:32:53.980        NaN  2022-06-26 08:30:00  37957585
# 4       2022-06-01 11:30:53.633        NaN  2022-06-02 23:00:00  37584530
# ...                         ...        ...                  ...       ...
# 101012  2022-06-01 00:20:14.280        NaN  2022-06-04 12:10:00  37579327
# 101013  2022-10-29 20:54:31.330        NaN  2022-11-01 15:30:00  39789479
# 101014  2022-09-03 17:57:22.067        NaN  2022-09-13 09:30:00  38991563
# 101015  2022-09-29 13:15:51.303        NaN  2022-09-29 17:30:00  39406503
# 101016  2022-03-31 13:29:11.530        NaN  2022-04-05 17:10:00  36742809
#
#          TicketID  ReserveStatus    UserID   Male       Price  CouponDiscount  \
# ...

# %%
test_data = pd.read_csv('../data/test_data.csv')
test_data
# Out:
#                        Created               CancelTime        DepartureTime  \
# 0      2022-07-22 12:52:35.293                      NaN  2022-08-03 17:00:00
# 1      2022-05-16 10:55:29.397  2022-05-18 11:35:15.643  2022-05-19 17:00:00
# 2      2022-02-13 16:10:33.870                      NaN  2022-02-15 22:45:00
# 3      2022-05-01 17:56:18.530                      NaN  2022-05-06 14:30:00
# 4      2022-05-19 18:40:48.760                      NaN  2022-05-21 12:30:00
# ...                        ...                      ...                  ...
# 43288  2022-10-06 16:57:16.053                      NaN  2022-10-07 21:00:00
# 43289  2022-06-14 13:19:26.413                      NaN  2022-06-18 07:15:00
# 43290  2022-10-23 15:48:03.947                      NaN  2022-10-23 20:25:00
# 43291  2022-09-18 21:18:01.730  2022-09-19 15:40:44.707  2022-09-20 20:00:00
# 43292  2022-07-27 22:08:17.510  2022-07-30 19:19:29.357  2022-08-03 21:00:00
#
# ...

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در این سوال شما می‌توانید از هر تکنیک پیش‌پردازش/مهندسی ویژگی که در فصل‌های گذشته آموختید، استفاده کنید.
#     <br>
#     تکنیک‌هایی که استفاده می‌کنید به شکل مستقیم مورد ارزیابی توسط سامانه داوری قرار <b>نمی‌گیرند.</b> بلکه همه آن‌ها در دقت مدل شما تاثیر خواهند گذاشت؛ بنابراین هر چه پیش‌پردازش/مهندسی ویژگی بهتری انجام دهید تا دقت مدل بهبود پیدا کند، امتیاز بیشتری از این سوال کسب خواهید کرد.
# </font>
# </p>

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در ابتدا ستون‌هایی که ظاهرا در تعیین نوع سفر نقش کم‌رنگی دارند را حذف و بخشی از داده را هم برای اعتبارسنجی جدا می‌کنیم:
# </font>
# </p>

# %%
from sklearn.model_selection import train_test_split

to_be_dropped_cols = ['Created', 'BillID', 'TicketID', 'UserID', 'CancelTime', 'HashPassportNumber_p', 'HashEmail',
                        'BuyerMobile', 'NationalCode', 'VehicleType']

summarized_train_data = train_data.drop(columns=to_be_dropped_cols, axis=1)
summarized_test_data = test_data.drop(columns=to_be_dropped_cols, axis=1)

x_train = summarized_train_data.drop(columns=['TripReason'], axis=1)
y_train = summarized_train_data['TripReason']

# %%
x_train
# Out:
#               DepartureTime  ReserveStatus   Male       Price  CouponDiscount  \
# 0       2022-11-02 23:59:00              5   True   6600000.0         34425.0
# 1       2022-08-18 04:15:00              5   True   9500000.0             0.0
# 2       2022-09-21 11:00:00              3  False   2000000.0             0.0
# 3       2022-06-26 08:30:00              2  False     40000.0             0.0
# 4       2022-06-02 23:00:00              3   True   1130000.0             0.0
# ...                     ...            ...    ...         ...             ...
# 101012  2022-06-04 12:10:00              5   True   5900000.0             0.0
# 101013  2022-11-01 15:30:00              2   True    926500.0             0.0
# 101014  2022-09-13 09:30:00              5   True  30000000.0             0.0
# 101015  2022-09-29 17:30:00              3   True    980000.0             0.0
# 101016  2022-04-05 17:10:00              2   True   3168000.0             0.0
#
# ...

# %%
summarized_test_data
# Out:
#              DepartureTime  ReserveStatus   Male      Price  CouponDiscount  \
# 0      2022-08-03 17:00:00              3  False  1220000.0             0.0
# 1      2022-05-19 17:00:00              5   True  2830000.0             0.0
# 2      2022-02-15 22:45:00              3   True  1480000.0             0.0
# 3      2022-05-06 14:30:00              3  False  2450000.0             0.0
# 4      2022-05-21 12:30:00              2   True  1965500.0             0.0
# ...                    ...            ...    ...        ...             ...
# 43288  2022-10-07 21:00:00              3   True   800000.0             0.0
# 43289  2022-06-18 07:15:00              5  False  7827000.0             0.0
# 43290  2022-10-23 20:25:00              3  False   370000.0             0.0
# 43291  2022-09-20 20:00:00              5   True  2520000.0             0.0
# 43292  2022-08-03 21:00:00              5   True  2150000.0             0.0
#
# ...

# %%
x_train.isna().sum()
# Out:
# DepartureTime         0
# ReserveStatus         0
# Male                  0
# Price                 0
# CouponDiscount        0
# From                  0
# To                    0
# Domestic              0
# VehicleClass      38450
# Vehicle               0
# Cancel                0
# dtype: int64

# %%
summarized_test_data.isna().sum()
# Out:
# DepartureTime         0
# ReserveStatus         0
# Male                  0
# Price                 0
# CouponDiscount        0
# From                  0
# To                    0
# Domestic              0
# VehicleClass      16338
# Vehicle               0
# Cancel                0
# dtype: int64

# %%
x_train.describe()
# Out:
#        ReserveStatus         Price  CouponDiscount       Domestic  \
# count  101017.000000  1.010170e+05    1.010170e+05  101017.000000
# mean        3.158053  3.203236e+06    4.777172e+03       0.992130
# std         1.073276  7.349195e+06    6.127747e+04       0.088363
# min         2.000000 -1.514000e+06   -2.000000e+03       0.000000
# 25%         2.000000  1.075000e+06    0.000000e+00       1.000000
# 50%         3.000000  1.690000e+06    0.000000e+00       1.000000
# 75%         4.000000  3.043500e+06    0.000000e+00       1.000000
# max         5.000000  3.837646e+08    1.443333e+07       1.000000
#
#               Cancel
# count  101017.000000
# mean        0.151618
# std         0.358652
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
summarized_test_data.describe()
# Out:
#        ReserveStatus         Price  CouponDiscount      Domestic       Cancel
# count   43293.000000  4.329300e+04    4.329300e+04  43293.000000  43293.00000
# mean        3.169727  3.291000e+06    4.925742e+03      0.991661      0.15111
# std         1.080760  7.627058e+06    6.615554e+04      0.090935      0.35816
# min         2.000000  3.250000e+04    0.000000e+00      0.000000      0.00000
# 25%         2.000000  1.080000e+06    0.000000e+00      1.000000      0.00000
# 50%         3.000000  1.690000e+06    0.000000e+00      1.000000      0.00000
# 75%         4.000000  3.070000e+06    0.000000e+00      1.000000      0.00000
# max         5.000000  3.837646e+08    1.082500e+07      1.000000      1.00000

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     با توجه به وجود قیمت و تخفیف اعمال شده منفی روی بلیط‌های داده آموزشی پس داده‌های outlier در این دو ستون داریم و بایستی این داده‌ها را با میانگین داده‌هایی که outlier نیستند، جایگزین کنیم. هم‌چنین باید فکری به حال ستون‌های دسته‌ای کرد و آن‌ها را هم encode کرد و در انتها هم بایستی فکری برای مقادیر گم‌شده در ستون VehicleClass کرد.
# </font>
# </p>

# %%
price_outliers = x_train[(x_train['Price'] <= 0)]['Price']

s1_price = sum(x_train['Price'])
s2_price = sum(price_outliers)

mean_without_price_outliers = (s1_price - s2_price) // (x_train['Price'].shape[0] - price_outliers.shape[0])

x_train.loc[(x_train['Price'] <= 0), 'Price'] = mean_without_price_outliers

discount_outliers = x_train[(x_train['CouponDiscount'] < 0)]['CouponDiscount']

s1_discount = sum(x_train['CouponDiscount'])
s2_discount = sum(discount_outliers)

mean_without_discount_outliers = (s1_discount - s2_discount) // (x_train['CouponDiscount'].shape[0] - discount_outliers.shape[0])

x_train.loc[(x_train['CouponDiscount'] < 0), 'CouponDiscount'] = mean_without_discount_outliers

# %%
def convert_departure_time(df):
    from datetime import datetime as dt

    year = []
    month = []
    day_of_week = []

    for date in df['DepartureTime']:
        d = dt.strptime(date, '%Y-%m-%d %H:%M:%S')
        year.append(d.year)
        month.append(d.month)
        day_of_week.append(d.strftime('%A'))
    
    df_y_m_d = pd.DataFrame({'Year': year, 'Month': month, 'DayOfWeek': day_of_week})

    df = df.drop(columns=['DepartureTime'], axis=1)
    df = df.join(df_y_m_d)

    return df

# %%
x_train = convert_departure_time(x_train)
summarized_test_data = convert_departure_time(summarized_test_data)

# %%
day_of_week_mapping = {'Saturday': 1, 'Sunday': 2, 'Monday': 3, 'Tuesday': 4, 'Wednesday': 5,
                        'Thursday': 6, 'Friday': 7}

x_train['DayOfWeek'] = x_train['DayOfWeek'].map(day_of_week_mapping)
summarized_test_data['DayOfWeek'] = summarized_test_data['DayOfWeek'].map(day_of_week_mapping)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

cols = ['From', 'To', 'Vehicle']

x_train['train'] = 1
summarized_test_data['train'] = 0

combined = pd.concat([x_train, summarized_test_data])

for col in cols:
    le.fit(combined[col])
    x_train[col] = le.transform(x_train[col])
    summarized_test_data[col] = le.transform(summarized_test_data[col])

x_train.drop(columns=['train'], inplace=True)
summarized_test_data.drop(columns=['train'], inplace=True)

# %%
x_train['Male'] = x_train['Male'].map({True: 1, False: 0})
summarized_test_data['Male'] = summarized_test_data['Male'].map({True: 1, False: 0})

# %%
x_train['VehicleClass'] = x_train['VehicleClass'].map({True: 1, False: 0})
summarized_test_data['VehicleClass'] = summarized_test_data['VehicleClass'].map({True: 1, False: 0})

# %%
x_train
# Out:
#         ReserveStatus  Male       Price  CouponDiscount  From   To  Domestic  \
# 0                   5     1   6600000.0         34425.0   225   85         1
# 1                   5     1   9500000.0             0.0   175   85         1
# 2                   3     0   2000000.0             0.0   139   39         1
# 3                   2     0     40000.0             0.0    65   91         1
# 4                   3     1   1130000.0             0.0    69  254         1
# ...               ...   ...         ...             ...   ...  ...       ...
# 101012              5     1   5900000.0             0.0   139  303         1
# 101013              2     1    926500.0             0.0   185   85         1
# 101014              5     1  30000000.0             0.0   190   85         0
# 101015              3     1    980000.0             0.0    27  318         1
# 101016              2     1   3168000.0             0.0   216   85         1
#
# ...

# %%
summarized_test_data
# Out:
#        ReserveStatus  Male      Price  CouponDiscount  From   To  Domestic  \
# 0                  3     0  1220000.0             0.0    69   33         1
# 1                  5     1  2830000.0             0.0   176  210         1
# 2                  3     1  1480000.0             0.0   215   17         1
# 3                  3     0  2450000.0             0.0   200  182         1
# 4                  2     1  1965500.0             0.0   109   85         1
# ...              ...   ...        ...             ...   ...  ...       ...
# 43288              3     1   800000.0             0.0   216  144         1
# 43289              5     0  7827000.0             0.0   233   85         1
# 43290              3     0   370000.0             0.0    69  210         1
# 43291              5     1  2520000.0             0.0    69  230         1
# 43292              5     1  2150000.0             0.0    35   85         1
#
#        VehicleClass  Vehicle  Cancel  Year  Month  DayOfWeek
# ...

# %%
target = x_train[(x_train['VehicleClass'].isna())]
train_col = x_train[~(x_train['VehicleClass'].isna())]

train_col_x = train_col.drop(columns=['VehicleClass'], axis=1)
train_col_y = train_col['VehicleClass']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import f1_score

g_s = GridSearchCV(RandomForestClassifier(), 
                {'n_estimators': [50, 75, 100], 'max_depth': [5, 10, 15, 20],
                    'min_samples_split':[1, 2, 3, 4]},
                    scoring='f1')

g_s.fit(train_col_x, train_col_y)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [5, 10, 15, 20],
#                          'min_samples_split': [1, 2, 3, 4],
#                          'n_estimators': [50, 75, 100]},
#              scoring='f1')

# %%
g_s.best_params_
# Out:
# {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 75}

# %%
model = RandomForestClassifier(n_estimators = 75, min_samples_split = 2, max_depth = 20)

model.fit(train_col_x, train_col_y)

train_col_y_pred = model.predict(train_col_x)

f1_score(train_col_y, train_col_y_pred)
# Out:
# 0.9959966083867299

# %%
X = x_train.dropna().drop('VehicleClass', axis=1)
y = x_train.dropna()['VehicleClass']
model = RandomForestClassifier(n_estimators = 75, min_samples_split = 2, max_depth = 20).fit(X, y)

x_train['VehicleClass'] = x_train['VehicleClass'].fillna(
    pd.Series(model.predict(x_train.drop('VehicleClass', axis=1))))

# %%
x_train.isna().sum()
# Out:
# ReserveStatus     0
# Male              0
# Price             0
# CouponDiscount    0
# From              0
# To                0
# Domestic          0
# VehicleClass      0
# Vehicle           0
# Cancel            0
# Year              0
# Month             0
# DayOfWeek         0
# dtype: int64

# %%
summarized_test_data['VehicleClass'] = summarized_test_data['VehicleClass'].fillna(
    pd.Series(model.predict(summarized_test_data.drop('VehicleClass', axis=1)))
)

# %%
summarized_test_data.isna().sum()
# Out:
# ReserveStatus     0
# Male              0
# Price             0
# CouponDiscount    0
# From              0
# To                0
# Domestic          0
# VehicleClass      0
# Vehicle           0
# Cancel            0
# Year              0
# Month             0
# DayOfWeek         0
# dtype: int64

# %%
x_train
# Out:
#         ReserveStatus  Male       Price  CouponDiscount  From   To  Domestic  \
# 0                   5     1   6600000.0         34425.0   225   85         1
# 1                   5     1   9500000.0             0.0   175   85         1
# 2                   3     0   2000000.0             0.0   139   39         1
# 3                   2     0     40000.0             0.0    65   91         1
# 4                   3     1   1130000.0             0.0    69  254         1
# ...               ...   ...         ...             ...   ...  ...       ...
# 101012              5     1   5900000.0             0.0   139  303         1
# 101013              2     1    926500.0             0.0   185   85         1
# 101014              5     1  30000000.0             0.0   190   85         0
# 101015              3     1    980000.0             0.0    27  318         1
# 101016              2     1   3168000.0             0.0   216   85         1
#
# ...

# %%
summarized_test_data
# Out:
#        ReserveStatus  Male      Price  CouponDiscount  From   To  Domestic  \
# 0                  3     0  1220000.0             0.0    69   33         1
# 1                  5     1  2830000.0             0.0   176  210         1
# 2                  3     1  1480000.0             0.0   215   17         1
# 3                  3     0  2450000.0             0.0   200  182         1
# 4                  2     1  1965500.0             0.0   109   85         1
# ...              ...   ...        ...             ...   ...  ...       ...
# 43288              3     1   800000.0             0.0   216  144         1
# 43289              5     0  7827000.0             0.0   233   85         1
# 43290              3     0   370000.0             0.0    69  210         1
# 43291              5     1  2520000.0             0.0    69  230         1
# 43292              5     1  2150000.0             0.0    35   85         1
#
#        VehicleClass  Vehicle  Cancel  Year  Month  DayOfWeek
# ...

# %%
y_train = y_train.map({'Work': 1, 'Int': 0})
y_train
# Out:
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 101012    0
# 101013    1
# 101014    0
# 101015    1
# 101016    1
# Name: TripReason, Length: 101017, dtype: int64

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     حال که داده را پاکسازی کرده و احتمالا ویژگی‌هایی را به آن افزوده یا از آن حذف کرده‌اید، وقت آن است که مدلی آموزش دهید که بتواند متغیر هدف این مسئله را پیش‌بینی کند.
#     <br>
#     بر خلاف سایر تمرین‌های کالج، در این تمرین شما مجاز هستید از هر مدلی که آموخته‌اید استفاده کنید. به عبارت بهتر، هدف این سوال پیش‌بینی هرچه بهتر متغیر هدف مسئله است. انتظار ما این است که نحوه کار با کتابخانه‌های یادگیری ماشین را در حدی آموخته باشید که بتوانید با بهترین عملکرد، مسئله را حل کنید!
# </font>
# </p>

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.02, random_state=17)

# %%
g_s = GridSearchCV(RandomForestClassifier(), 
                {'n_estimators': [50, 75, 100], 'max_depth': [10, 15, 20, 25],
                    'min_samples_split':[1, 2, 3, 4]},
                    scoring='f1')

g_s.fit(x_train, y_train)

print(g_s.best_params_)
# Out:
# {'max_depth': 25, 'min_samples_split': 3, 'n_estimators': 100}

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معیار ارزیابی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     معیاری که برای ارزیابی عملکرد مدل انتخاب کرده‌ایم، <code>f1_score</code> نام دارد.
#     <br>
#     این معیار، سنجه ارزیابی کیفیت مدل شماست. به عبارت بهتر در سامانه داوری هم از همین معیار برای نمره‌دهی استفاده شده است.
#     <br>
#     پیشنهاد می‌شود با توجه به این معیار، عملکرد مدل خود را بر روی مجموعه داده آموزش یا اعتبارسنجی ارزیابی کنید.
# </font>
# </p>

# %%
# evaluate model
from sklearn.metrics import  f1_score, classification_report, confusion_matrix

model = RandomForestClassifier(n_estimators=100, min_samples_split=3, max_depth=25)
model.fit(x_train, y_train)

y_train_pred = model.predict(x_train)
y_val_pred = model.predict(x_val)

print(f'training f1 score: {f1_score(y_train, y_train_pred)}')
print(f'validation f1 score: {f1_score(y_val, y_val_pred)}')
# Out:
# training f1 score: 0.9403190368160627
# validation f1 score: 0.8254529385771101

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazir" size=3>
#  جهت کسب امتیاز کامل نیاز است تا پاسخ شما حداقل امتیاز <code>75%</code> را با توجه به معیار معرفی‌شده کسب نماید.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#  پیش‌بینی برای داده تست و خروجی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     پس از مهندسی ویژگی و مدلسازی، الگوریتمی دارید که می‌تواند شما را از متغیرهای مستقل به متغیر هدف برساند.
#     <br>
#     از این مدل برای پیش‌بینی نمونه‌های موجود در داده تست استفاده کنید و نتایج را در قالب جدول (<code>dataframe</code>) زیر آماده کنید.
# </font>
# </p>
#
# <div dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |------|---|
# |TripReason|دلیل سفر|
#
# </font>
# </div>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     اسم دیتافریم باید <i>submission</i> باشد؛ در غیر این صورت، سامانه داوری نمی‌تواند تلاش‌ شما را ارزیابی کند.
#     <br>
#     این دیتافریم تنها شامل ۱ ستون با اسم <i>TripReason</i> است و ۴۳۲۹۳ سطر دارد.
#     <br>
#     به ازای هر سطر موجود در دیتافریم <i>test</i> شما باید یک مقدار پیشبینی شده داشته باشید.
#     <br>
#     جدول زیر، ۵ سطر ابتدایی دیتافریم <code>submission</code> را نشان می‌دهد. البته در جواب شما، مقادیر ستون <i>TripReason</i> ممکن است متفاوت باشد.
# </font>
# </p>
#
# <div style="text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# ||TripReason|
# |----|-----|
# |0|Work|
# |1|Work|
# |2|Int|
# |3|Int|
# |4|Work|
#
# </font>
# </div>

# %%
# predict test samples
y_test_pred = model.predict(summarized_test_data)

submission = pd.DataFrame({'TripReason': y_test_pred})

submission['TripReason'] = submission['TripReason'].map({1: 'Work', 0: 'Int'})

submission
# Out:
#       TripReason
# 0           Work
# 1            Int
# 2           Work
# 3           Work
# 4           Work
# ...          ...
# 43288       Work
# 43289       Work
# 43290       Work
# 43291       Work
# 43292        Int
#
# [43293 rows x 1 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)
            
submission.to_csv('submission.csv', index=False)
file_names = ['tafrihi.ipynb', 'submission.csv']
compress(file_names)
# Out:
# File Paths:
# ['tafrihi.ipynb', 'submission.csv']
