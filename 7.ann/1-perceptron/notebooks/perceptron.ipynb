# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پرسپترون
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     به یک تمرین اساسی از پایه‌ای‌ترین مباحث شبکه‌های عصبی خوش آمدید! در این تمرین رویکرد متفاوتی را در پیش خواهیم گرفت و قصد داریم ساختار پرسپترون و الگوریتم آموزش آن را که در درسنامه‌های پیشین آموختید مستقیماً پیاده‌سازی کنیم. کدنویسی در این سطح به شما کمک خواهد کرد که به شکل عملی درک عمیق‌تری از نحوه‌ی کار این مدل پیدا کنید و در آینده نیز هنگام مواجه با مدل‌های مختلف شبکه‌های عصبی قادر به تحلیل آسان‌تر ساختار آن‌ها باشید. پس از طراحی پرسپترون، آن را روی مجموعه‌داده‌ی مشهور <i>گل‌های زنبق (iris)</i> آموزش داده و عملکرد دو روش مختلف آموزش پرسپترون، یعنی قاعده‌ی پرسپترون و قاعده‌ی دلتا را بر روی این مجموعه‌داده ارزیابی خواهیم کرد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد کنید.
# </font>
# </p>

# %%
import json
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from inspect import getsource

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معرفی مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در این تمرین از مجموعه‌‌داده‌ی ساده اما مشهور گل‌های زنبق (iris) استفاده خواهیم کرد. این مجموعه‌داده شامل سه دسته (نوع گیاه) است که از هر دسته 50 نمونه داده وجود دارد. هر داده دارای یک برچسب و چهار ویژگی است که در جدول زیر معرفی شده‌اند.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |SepalLengthCm|طول کاسبرگ (سانتی‌متر)|
# |SepalWidthCm|عرض کاسبرگ (سانتی‌متر)|
# |PetalLengthCm|طول گلبرگ (سانتی‌متر)|
# |PetalWidthCm|عرض گلبرگ (سانتی‌متر)|
# |Species|نوع گیاه (متغیر هدف)|
#
# </font>
# </div>
# </center>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# خواندن مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در ابتدا نیاز است فایل‌ مجموعه‌داده را بخوانید. برای این تمرین مجموعه‌ی آزمونی در نظر گرفته نشده و هدف تنها پیاده‌سازی و تحلیل مدل است. بنابراین کل مجموعه‌داده را می‌توانید از فایل <code>iris.csv</code> موجود در پوشه‌ی مسئله خوانده و از نمونه‌های موجود در آن برای آموزش پرسپترون استفاده کنید. توجه داشته باشید که نیازی به ستون <code>Id</code> ندارید و می‌توانید آن را از دیتافریم خود حذف کنید.
# </font>
# </p>

# %%
train_data = pd.read_csv('../data/iris.csv')
train_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
train_data.drop(columns=['Id'], inplace=True)
train_data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
train_data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     اگر به مقادیر ستون <code>Species</code> نگاه کرده باشید، دریافته‌اید که این مجموعه‌داده دارای سه کلاس <code>Iris-setosa</code> ،<code>Iris-versicolor</code> و <code>Iris-virginica</code> است.
#     <br>
#     از آنجا که یک پرسپترون واحد قادر به دسته‌بندی دوکلاسه هست در این تمرین قصد داریم سه مدل مختلف را آموزش دهیم که هرکدام از آن‌ها بین یک ترکیب دوتایی از سه دسته ممکن تصمیم‌گیری می‌کند. یعنی قرار است تا سه پرسپترون را به شکل زیر آموزش دهیم:
# </font>
# </p>
# <ul dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <li>تصمیم‌گیری بین دو دسته‌ی <code>Iris-setosa</code> و <code>Iris-versicolor</code></li>
#     <li>تصمیم‌گیری بین دو دسته‌ی <code>Iris-setosa</code> و <code>Iris-virginica</code></li>
#     <li>تصمیم‌گیری بین دو دسته‌ی <code>Iris-versicolor</code> و <code>Iris-virginica</code></li>
# </font>
# </ul>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     این امر همچنین به ما کمک می‌کند تا به‌صورت تجربی کشف کنیم که کدام دسته از سایر دسته‌ها به‌صورت خطی تفکیک‌پذیر است.
# </font>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     بنابراین از شما خواسته می‌شود که دیتافریم اصلی را به سه دیتافریم کوچک‌تر (با نام‌های <code>df2</code> ،<code>df1</code> و <code>df3</code>) تقسیم کنید، به شکلی که در هر دیتافریم تنها نمونه‌های مربوط به یکی از حالت‌های لیست بالا وجود داشته باشد. به عنوان مثال در دیتافریم نخست یعنی <code>df1</code> تنها نمونه‌های حالت اول یعنی دسته‌های <code>Iris-setosa</code> و <code>Iris-versicolor</code> وجود داشته باشد.
# </font>

# %%
df1 = train_data[(train_data['Species'] == 'Iris-setosa') | (train_data['Species'] == 'Iris-versicolor')].reset_index(drop=True)

df2 = train_data[(train_data['Species'] == 'Iris-setosa') | (train_data['Species'] == 'Iris-virginica')].reset_index(drop=True)

df3 = train_data[(train_data['Species'] == 'Iris-versicolor') | (train_data['Species'] == 'Iris-virginica')].reset_index(drop=True)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# کد زیر دیتافریم‌های شما را ذخیره می‌کند تا در انتهای نت‌بوک به فایل جواب شما اضافه شود. سه دیتافریم بالا از نظر تعداد نمونه، ستون‌ها و مقادیر موجود در ستون <code>Species</code> داوری خواهند شد. نیازی به تغییر کد نیست و کافیست تنها سلول را اجرا نمایید.
# </font>

# %%
df1.to_csv('df1.csv', index=False)
df2.to_csv('df2.csv', index=False)
df3.to_csv('df3.csv', index=False)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     اکنون اگر قصد دارید می‌توانید پیش‌پردازش‌های دلخواه خود را بر روی مقادیر ویژگی‌ها انجام دهید. همچنین توجه داشته باشید مقادیر ستون برچسب را باید به شکل اعداد <code dir=ltr>+1</code> و <code dir=ltr>-1</code> کدگذاری کنید. علاوه بر این فراموش نکنید که ستون‌های ویژگی را از ستون متغیر هدف (برچسب) جدا کنید.
# </font>

# %%
x_df1 = df1.drop('Species', axis=1)
x_df2 = df2.drop('Species', axis=1)
x_df3 = df3.drop('Species', axis=1)

y_df1 = df1['Species']
y_df2 = df2['Species']
y_df3 = df3['Species']


y_df1_mapping = {'Iris-setosa': 1, 'Iris-versicolor': -1}
y_df2_mapping = {'Iris-setosa': 1, 'Iris-virginica': -1}
y_df3_mapping = {'Iris-virginica': 1, 'Iris-versicolor': -1}

y_df1 = y_df1.map(y_df1_mapping)
y_df2 = y_df2.map(y_df2_mapping)
y_df3 = y_df3.map(y_df3_mapping)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     اکنون که داده‌ها را پردازش و آماده کردید نوبت به قسمت اصلی یعنی مدل می‌رسد. همانطور که در ابتدا ذکر کردیم در این تمرین دیگر خبری از کتابخانه‌ی آماده‌ی <code>scikit-learn</code> نیست. در اینجا از شما خواسته شده تا یک مدل ساده‌ی پرسپترون را به دو حالت (قاعده‌ی پرسپترون و قاعده‌ی دلتا) از صفر پیاده کنید. برای این کار قدم به قدم هر جزء این مدل را شرح خواهیم داد تا نسبت به پیاده‌‌سازی آن اقدام کنید.
#     <br>
#     <b>نکته: </b>
#     در اعمال ریاضی و محاسباتی خود تنها از کتابخانه‌ی نامپای استفاده کنید و لیست‌های خود را نیز به شکل آرایه‌ی نامپای تعریف کنید.
#     <br>
# </font>
# </p>

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قاعده‌ی پرسپترون
# </font>
# </h3>
# <center>
#     <img src="perceptron_rule.png">
# <center>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
#     به منظور پیاده‌سازی مدل،‌ کلاسی با نام <code>Perceptron</code> تعریف خواهیم کرد که در هنگام ساخته شدن (<code>__init__</code>) یک ویژگی مرتبط با وزن‌ها را با نام <code>weights</code> به این کلاس اضافه می‌کند. بنابراین در هنگام پیاده‌سازی توابع جهت دسترسی به وزن‌های پرسپترون می‌توانید از <code>self.weights</code> استفاده کنید.
#     <br>
#     اکنون هرکدام از توابع مورد نیاز این کلاس را شرح خواهیم داد تا شما به پیاده‌سازی آن‌ها بپردازید:
#     <br>
#     <ul dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <li>
#         تابع <code>weighting</code> مقادیر ویژگی‌های یک نمونه را گرفته و آن را در بردار وزن ضرب نقطه‌ای می‌کند. سپس ورودی وزن‌دار شده به عنوان خروجی برگردانده می‌شود.
#         </li>
#         <li>
#         در تابعی به نام <code>activation</code> تابع فعال‌ساز را که در اینجا تابع علامت است پیاده خواهیم کرد. این تابع، ورودی وزن‌دار را گرفته و در صورتیکه حاصل بیشتر یا مساوی صفر بود خروجی <code>1</code> و در غیر این‌صورت خروجی <code dir=ltr>-1</code> تولید می‌کند.
#         </li>
#         <li>
#         تابع <code>predict</code> آرایه‌ای از نمونه‌ها را گرفته و آرایه‌ای شامل برچسب پیش‌بینی‌شده برای هرکدام از نمونه‌ها را بر می‌گرداند. در این تابع باید به ازای هر نمونه ابتدا آن را به کمک تابع <code>weighting</code> وزن دار کنید و حاصل را به تابع <code>activation</code> بدهید تا برچسب <code dir=ltr>+1</code> یا <code dir=ltr>-1</code> را برای نمونه تولید کند.
#         </li>
#         <li>
#         الگوریتم اصلی پرسپترون در واقع در تابع <code>fit</code> پیاده می‌شود. این تابع ورودی‌ها و هایپرپارامترهای زیر را گرفته و سپس طبق مراحلی که شرح خواهیم داد شروع به آموزش [وزن‌های] پرسپترون می‌کند.
#         </li>
#     </ul>
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ورودی|توضیحات|
# |:------:|:---:|
# |inputs|ویژگی‌های ورودی نمونه‌های آموزشی|
# |outputs|متغیر هدف (برچسب) نمونه‌‌های آموزشی|
# |learning_rate|نرخ یادگیری (η)|
# |epochs|تعداد دفعات آموزش بر روی تمام نمونه‌ها|
#
# </font>
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium; padding-right:40px;">
# <font face="vazir">
# در درسنامه‌ی پرسپترون اشاره کردیم که عبارت بایاس را می‌توان به کمک اضافه کردن یک ورودی ثابت <code>1</code> به ویژگی‌های ورودی تعبیه کرد. بنابراین در تابع <code>fit</code> ابتدا به اول ویژگی‌های هرکدام از نمونه‌ها عدد <code>1</code> را اضافه کنید (به عنوان مثال برای نمونه‌ی <code>inputs[i]</code>، باید <code>inputs[i][0]</code> برابر <code>1</code> باشد). با این کار یک واحد به طول بردار ویژگی نمونه‌ها اضافه خواهد شد. (فراموش نکنید که این کار را در هنگام پیش‌بینی یعنی تابع predict نیز باید انجام دهید.)
# <br>
# پس از آن نیاز است تا بردار وزن یعنی <code>self.weights</code> را ساخته و مقداردهی کنید. برای مقداردهی اولیه می‌توانید از اعداد تصادفی بین <code dir=ltr>0</code> تا <code dir=ltr>1</code> استفاده کنید.
# <br>
# سپس در یک حلقه به ازای هر دور (به تعداد <code>epochs</code>) باید یک‌بار کل مجموعه‌ی آموزشی را بررسی کنید. بنابراین در داخل این حلقه، یک حلقه‌ی دیگر خواهید داشت که هربار یکی از نمونه‌ها را بررسی می‌کند (به دلیل استفاده از روش کاهش گرادیان تصادفی در هر تکرار تنها یک نمونه بررسی و وزن‌ها آپدیت می‌شوند).
# <br>
# به ازای هر نمونه، ابتدا به کمک تابع <code>weighting</code> بردار ویژگی آن را در بردار وزن ضرب نقطه‌ای می‌کنیم تا ورودی وزن‌دار به دست آید. سپس حاصل به‌دست‌آمده را به تابع فعال‌سازی می‌دهیم تا مقدار خروجی مدل را تولید کند. حال با تفریق پیش‌بینی مدل از مقدار (برچسب) واقعی می‌توانیم اختلاف‌شان را به دست آوریم. سپس طبق فرمول‌های معرفی‌شده در درسنامه، با ضرب این اختلاف در نرخ یادگیری و ویژگی‌های ورودی و سپس جمع آن با مقادیر قبلی بردار وزن می‌توانیم به آپدیت بردار وزن بپردازیم.
# <br>
# پیشنهاد می‌شود در آخر هر دور نسبت به چاپ دقت مدل کنونی بر روی مجموعه‌ی آموزشی نیز اقدام کنید. برای این کار کافیست نمونه‌ها را به تابع <code>predict</code> بدهید تا پیش‌بینی مدل تولید شود و سپس به کمک تابع آماده‌ی <code>accuracy_score</code> دقت آن را به دست آورید.
# <br>
# <b>نکته: </b>
# در هیچ‌کدام از توابع خود به غیر از تابع <code>fit</code> چیزی را چاپ (<code>print</code>) نکنید، در غیر این‌صورت سیستم داوری قادر به امتیازدهی به توابع شما نخواهد بود.
# </font>
# </p>

# %%
class Perceptron:

    def __init__(self):
        self.weights = None

    def weighting(self, input):
        return np.dot(self.weights, input)


    def activation(self, weighted_input):
        if weighted_input >= 0:
            return 1
        else:
            return -1

    def predict(self, inputs):
        bias_added_inputs = np.insert(inputs, 0, 1, axis=1)

        outputs = np.zeros(inputs.shape[0])

        for i in range(bias_added_inputs.shape[0]):
            weighted_input = self.weighting(bias_added_inputs[i])
            activation_output = self.activation(weighted_input)
            outputs[i] = activation_output

        return outputs

    def fit(self, inputs, outputs, learning_rate, epochs):
        bias_added_inputs = np.insert(inputs, 0, 1, axis=1)
        
        self.weights = np.random.rand(5)

        for i in range(epochs):
            for j in range(bias_added_inputs.shape[0]):
                weighted_input = self.weighting(bias_added_inputs[j])
                activation_output = self.activation(weighted_input)
                error = outputs[j] - activation_output
                self.weights += learning_rate * error * bias_added_inputs[j]

            ouput_pred = self.predict(inputs)
            print(f'model accuracy after epoch{i+1}: {accuracy_score(outputs, ouput_pred)}')

# %% [markdown]
# <h4 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آموزش مدل
# </font>
# </h4>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
#     پس از طراحی ساختار پرسپترون می‌توانید به کمک <code dir=ltr>Perceptron()</code> ابتدا یک نمونه از این کلاس بسازید و سپس تابع <code>fit</code> را با آرگومان‌های مناسب صدا بزنید تا آموزش مدل آغاز شود. این کار را برای هر سه حالت ورودی انجام دهید. پیشنهاد می‌شود مقادیر مختلف نرخ یادگیری مانند 0.1، 0.01، 0.001 و... را آزمایش و مقایسه کنید.
# </font>
# </p>

# %%
perceptron = Perceptron()
perceptron.fit(x_df1.to_numpy(), y_df1.to_numpy(), 0.01, 100)
# Out:
# model accuracy after epoch1: 0.5
# model accuracy after epoch2: 0.5
# model accuracy after epoch3: 0.74
# model accuracy after epoch4: 0.51
# model accuracy after epoch5: 0.5
# model accuracy after epoch6: 0.64
# model accuracy after epoch7: 0.62
# model accuracy after epoch8: 1.0
# model accuracy after epoch9: 1.0
# model accuracy after epoch10: 1.0
# model accuracy after epoch11: 1.0
# model accuracy after epoch12: 1.0
# model accuracy after epoch13: 1.0
# model accuracy after epoch14: 1.0
# model accuracy after epoch15: 1.0
# model accuracy after epoch16: 1.0
# model accuracy after epoch17: 1.0
# model accuracy after epoch18: 1.0
# model accuracy after epoch19: 1.0
# model accuracy after epoch20: 1.0
# model accuracy after epoch21: 1.0
# model accuracy after epoch22: 1.0
# model accuracy after epoch23: 1.0
# model accuracy after epoch24: 1.0
# model accuracy after epoch25: 1.0
# model accuracy after epoch26: 1.0
# model accuracy after epoch27: 1.0
# model accuracy after epoch28: 1.0
# model accuracy after epoch29: 1.0
# model accuracy after epoch30: 1.0
# model accuracy after epoch31: 1.0
# model accuracy after epoch32: 1.0
# model accuracy after epoch33: 1.0
# model accuracy after epoch34: 1.0
# model accuracy after epoch35: 1.0
# model accuracy after epoch36: 1.0
# model accuracy after epoch37: 1.0
# model accuracy after epoch38: 1.0
# model accuracy after epoch39: 1.0
# model accuracy after epoch40: 1.0
# model accuracy after epoch41: 1.0
# model accuracy after epoch42: 1.0
# model accuracy after epoch43: 1.0
# model accuracy after epoch44: 1.0
# model accuracy after epoch45: 1.0
# model accuracy after epoch46: 1.0
# model accuracy after epoch47: 1.0
# model accuracy after epoch48: 1.0
# model accuracy after epoch49: 1.0
# model accuracy after epoch50: 1.0
# model accuracy after epoch51: 1.0
# model accuracy after epoch52: 1.0
# model accuracy after epoch53: 1.0
# model accuracy after epoch54: 1.0
# model accuracy after epoch55: 1.0
# model accuracy after epoch56: 1.0
# model accuracy after epoch57: 1.0
# model accuracy after epoch58: 1.0
# model accuracy after epoch59: 1.0
# model accuracy after epoch60: 1.0
# model accuracy after epoch61: 1.0
# model accuracy after epoch62: 1.0
# model accuracy after epoch63: 1.0
# model accuracy after epoch64: 1.0
# model accuracy after epoch65: 1.0
# model accuracy after epoch66: 1.0
# model accuracy after epoch67: 1.0
# model accuracy after epoch68: 1.0
# model accuracy after epoch69: 1.0
# model accuracy after epoch70: 1.0
# model accuracy after epoch71: 1.0
# model accuracy after epoch72: 1.0
# model accuracy after epoch73: 1.0
# model accuracy after epoch74: 1.0
# model accuracy after epoch75: 1.0
# model accuracy after epoch76: 1.0
# model accuracy after epoch77: 1.0
# model accuracy after epoch78: 1.0
# model accuracy after epoch79: 1.0
# model accuracy after epoch80: 1.0
# model accuracy after epoch81: 1.0
# model accuracy after epoch82: 1.0
# model accuracy after epoch83: 1.0
# model accuracy after epoch84: 1.0
# model accuracy after epoch85: 1.0
# model accuracy after epoch86: 1.0
# model accuracy after epoch87: 1.0
# model accuracy after epoch88: 1.0
# model accuracy after epoch89: 1.0
# model accuracy after epoch90: 1.0
# model accuracy after epoch91: 1.0
# model accuracy after epoch92: 1.0
# model accuracy after epoch93: 1.0
# model accuracy after epoch94: 1.0
# model accuracy after epoch95: 1.0
# model accuracy after epoch96: 1.0
# model accuracy after epoch97: 1.0
# model accuracy after epoch98: 1.0
# model accuracy after epoch99: 1.0
# model accuracy after epoch100: 1.0

# %%
perceptron = Perceptron()
perceptron.fit(x_df2.to_numpy(), y_df2.to_numpy(), 0.1, 100)
# Out:
# model accuracy after epoch1: 0.5
# model accuracy after epoch2: 0.5
# model accuracy after epoch3: 1.0
# model accuracy after epoch4: 1.0
# model accuracy after epoch5: 1.0
# model accuracy after epoch6: 1.0
# model accuracy after epoch7: 1.0
# model accuracy after epoch8: 1.0
# model accuracy after epoch9: 1.0
# model accuracy after epoch10: 1.0
# model accuracy after epoch11: 1.0
# model accuracy after epoch12: 1.0
# model accuracy after epoch13: 1.0
# model accuracy after epoch14: 1.0
# model accuracy after epoch15: 1.0
# model accuracy after epoch16: 1.0
# model accuracy after epoch17: 1.0
# model accuracy after epoch18: 1.0
# model accuracy after epoch19: 1.0
# model accuracy after epoch20: 1.0
# model accuracy after epoch21: 1.0
# model accuracy after epoch22: 1.0
# model accuracy after epoch23: 1.0
# model accuracy after epoch24: 1.0
# model accuracy after epoch25: 1.0
# model accuracy after epoch26: 1.0
# model accuracy after epoch27: 1.0
# model accuracy after epoch28: 1.0
# model accuracy after epoch29: 1.0
# model accuracy after epoch30: 1.0
# model accuracy after epoch31: 1.0
# model accuracy after epoch32: 1.0
# model accuracy after epoch33: 1.0
# model accuracy after epoch34: 1.0
# model accuracy after epoch35: 1.0
# model accuracy after epoch36: 1.0
# model accuracy after epoch37: 1.0
# model accuracy after epoch38: 1.0
# model accuracy after epoch39: 1.0
# model accuracy after epoch40: 1.0
# model accuracy after epoch41: 1.0
# model accuracy after epoch42: 1.0
# model accuracy after epoch43: 1.0
# model accuracy after epoch44: 1.0
# model accuracy after epoch45: 1.0
# model accuracy after epoch46: 1.0
# model accuracy after epoch47: 1.0
# model accuracy after epoch48: 1.0
# model accuracy after epoch49: 1.0
# model accuracy after epoch50: 1.0
# model accuracy after epoch51: 1.0
# model accuracy after epoch52: 1.0
# model accuracy after epoch53: 1.0
# model accuracy after epoch54: 1.0
# model accuracy after epoch55: 1.0
# model accuracy after epoch56: 1.0
# model accuracy after epoch57: 1.0
# model accuracy after epoch58: 1.0
# model accuracy after epoch59: 1.0
# model accuracy after epoch60: 1.0
# model accuracy after epoch61: 1.0
# model accuracy after epoch62: 1.0
# model accuracy after epoch63: 1.0
# model accuracy after epoch64: 1.0
# model accuracy after epoch65: 1.0
# model accuracy after epoch66: 1.0
# model accuracy after epoch67: 1.0
# model accuracy after epoch68: 1.0
# model accuracy after epoch69: 1.0
# model accuracy after epoch70: 1.0
# model accuracy after epoch71: 1.0
# model accuracy after epoch72: 1.0
# model accuracy after epoch73: 1.0
# model accuracy after epoch74: 1.0
# model accuracy after epoch75: 1.0
# model accuracy after epoch76: 1.0
# model accuracy after epoch77: 1.0
# model accuracy after epoch78: 1.0
# model accuracy after epoch79: 1.0
# model accuracy after epoch80: 1.0
# model accuracy after epoch81: 1.0
# model accuracy after epoch82: 1.0
# model accuracy after epoch83: 1.0
# model accuracy after epoch84: 1.0
# model accuracy after epoch85: 1.0
# model accuracy after epoch86: 1.0
# model accuracy after epoch87: 1.0
# model accuracy after epoch88: 1.0
# model accuracy after epoch89: 1.0
# model accuracy after epoch90: 1.0
# model accuracy after epoch91: 1.0
# model accuracy after epoch92: 1.0
# model accuracy after epoch93: 1.0
# model accuracy after epoch94: 1.0
# model accuracy after epoch95: 1.0
# model accuracy after epoch96: 1.0
# model accuracy after epoch97: 1.0
# model accuracy after epoch98: 1.0
# model accuracy after epoch99: 1.0
# model accuracy after epoch100: 1.0

# %%
perceptron = Perceptron()
perceptron.fit(x_df3.to_numpy(), y_df3.to_numpy(), 0.001, 100)
# Out:
# model accuracy after epoch1: 0.5
# model accuracy after epoch2: 0.5
# model accuracy after epoch3: 0.5
# model accuracy after epoch4: 0.5
# model accuracy after epoch5: 0.5
# model accuracy after epoch6: 0.5
# model accuracy after epoch7: 0.5
# model accuracy after epoch8: 0.5
# model accuracy after epoch9: 0.5
# model accuracy after epoch10: 0.5
# model accuracy after epoch11: 0.5
# model accuracy after epoch12: 0.5
# model accuracy after epoch13: 0.5
# model accuracy after epoch14: 0.5
# model accuracy after epoch15: 0.5
# model accuracy after epoch16: 0.5
# model accuracy after epoch17: 0.5
# model accuracy after epoch18: 0.5
# model accuracy after epoch19: 0.5
# model accuracy after epoch20: 0.5
# model accuracy after epoch21: 0.5
# model accuracy after epoch22: 0.5
# model accuracy after epoch23: 0.5
# model accuracy after epoch24: 0.52
# model accuracy after epoch25: 0.5
# model accuracy after epoch26: 0.5
# model accuracy after epoch27: 0.52
# model accuracy after epoch28: 0.5
# model accuracy after epoch29: 0.5
# model accuracy after epoch30: 0.51
# model accuracy after epoch31: 0.53
# model accuracy after epoch32: 0.5
# model accuracy after epoch33: 0.5
# model accuracy after epoch34: 0.51
# model accuracy after epoch35: 0.5
# model accuracy after epoch36: 0.5
# model accuracy after epoch37: 0.5
# model accuracy after epoch38: 0.51
# model accuracy after epoch39: 0.53
# model accuracy after epoch40: 0.5
# model accuracy after epoch41: 0.5
# model accuracy after epoch42: 0.51
# model accuracy after epoch43: 0.51
# model accuracy after epoch44: 0.56
# model accuracy after epoch45: 0.5
# model accuracy after epoch46: 0.51
# model accuracy after epoch47: 0.51
# model accuracy after epoch48: 0.56
# model accuracy after epoch49: 0.5
# model accuracy after epoch50: 0.51
# model accuracy after epoch51: 0.52
# model accuracy after epoch52: 0.53
# model accuracy after epoch53: 0.55
# model accuracy after epoch54: 0.56
# model accuracy after epoch55: 0.6
# model accuracy after epoch56: 0.51
# model accuracy after epoch57: 0.53
# model accuracy after epoch58: 0.55
# model accuracy after epoch59: 0.56
# model accuracy after epoch60: 0.59
# model accuracy after epoch61: 0.64
# model accuracy after epoch62: 0.53
# model accuracy after epoch63: 0.53
# model accuracy after epoch64: 0.55
# model accuracy after epoch65: 0.59
# model accuracy after epoch66: 0.6
# model accuracy after epoch67: 0.69
# model accuracy after epoch68: 0.53
# model accuracy after epoch69: 0.57
# model accuracy after epoch70: 0.6
# model accuracy after epoch71: 0.62
# model accuracy after epoch72: 0.71
# model accuracy after epoch73: 0.54
# model accuracy after epoch74: 0.59
# model accuracy after epoch75: 0.61
# model accuracy after epoch76: 0.63
# model accuracy after epoch77: 0.76
# model accuracy after epoch78: 0.58
# model accuracy after epoch79: 0.6
# model accuracy after epoch80: 0.62
# model accuracy after epoch81: 0.69
# model accuracy after epoch82: 0.53
# model accuracy after epoch83: 0.6
# model accuracy after epoch84: 0.62
# model accuracy after epoch85: 0.66
# model accuracy after epoch86: 0.75
# model accuracy after epoch87: 0.59
# model accuracy after epoch88: 0.62
# model accuracy after epoch89: 0.66
# model accuracy after epoch90: 0.77
# model accuracy after epoch91: 0.59
# model accuracy after epoch92: 0.62
# model accuracy after epoch93: 0.66
# model accuracy after epoch94: 0.77
# model accuracy after epoch95: 0.79
# model accuracy after epoch96: 0.62
# model accuracy after epoch97: 0.66
# model accuracy after epoch98: 0.74
# model accuracy after epoch99: 0.78
# model accuracy after epoch100: 0.8

# %% [markdown]
# <h4 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# 🤔
# پرسش
# </font>
# </h4>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
#     از میان سه حالت مختلفی که برای کلاس‌های مجموعه‌داده در نظر گرفتیم، یک یا چند حالت به‌صورت خطی تفکیک‌پذیر هستند. تفکیک‌پذیر خطی بودن آن‌ها را می‌توان طبق دقت به‌دست‌آمده توسط مدل نتیجه‌گیری کرد. طبق نتایج به‌دست‌آمده در اجرای خود فکر می‌کنید کدام حالت یا حالت‌ها به‌صورت خطی تفکیک‌پذیر هستند؟ پاسخ را در متغیر <code>linearly_separable</code> به شکل یک لیست وارد کنید. به عنوان مثال اگر پاسخ شما حالت اول یعنی کلاس‌های <code>Iris-setosa</code> و <code>Iris-versicolor</code> است آنگاه <code>linearly_separable</code> را به‌صورت <code>[1]</code> و اگر پاسخ شما مثلاً حالت دوم و سوم است آن را به شکل <code dir=ltr>[2, 3]</code> مقداردهی کنید.
# </font>
# </p>

# %%
linearly_separable = [1, 2]

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قاعده‌ی دلتا
# </font>
# </h3>
# <center>
# <img src="delta_rule.png">
# </center>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#     در این حالت می‌خواهیم کلاسی با نام <code>Adaline</code> بسازیم و  مدل را با قاعده‌ی دلتا آموزش دهیم. در اینجا از روش نزول گرادیان استفاده خواهیم کرد، یعنی تمام نمونه‌های آموزشی به‌صورت همزمان بر روی آپدیت وزن تاثیر می‌گذارند (برخلاف روش نزول گرادیان تصادفی که هربار یک نمونه دیده می‌شد). کد این مدل بسیار شبیه به حالت قبلی خواهد بود و تنها نیاز است چند مورد جزئی زیر را اعمال کنید:
#     <br>
#     <ul dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <li>
#         از آنجا که در این حالت از تابع فعال‌سازی خطی استفاده می‌شود تابع <code>activation</code> تنها همان ورودی وزن‌دار خود را بدون هیچ‌گونه تغییری خروجی می‌دهد.
#         </li>
#         <li>
#         در تابع <code>prediction</code> پس از وزن‌دار کردن و عبور از تابع فعال‌سازی، باید بررسی کنید که اگر حاصل بزرگتر یا مساوی صفر بود، مقدار پیش‌بینی <code dir=ltr>+1</code> و در غیر این‌صورت <code dir=ltr>-1</code> شود.
#         </li>
#         <li>
#         پیشنهاد می‌شود به جای اینکه یک حلقه بنویسید که خطای هر نمونه را محاسبه کند و در آخر از مجموع آن جهت آپدیت وزن استفاده کنید، همین کار را به‌صورت برداری انجام دهید (با ضرب نقطه‌ای ترانهاده‌ی ماتریس ورودی در بردار وزن).
#         </li>
#     </ul>
# </font>
# </p>

# %%
class Adaline:

    def __init__(self):
        self.weights = None

    def weighting(self, input):
        return np.dot(self.weights, input)

    def activation(self, weighted_input):
        return weighted_input

    def predict(self, inputs):
        samples_count = inputs.shape[0]

        bias_added_inputs = np.insert(inputs, 0, 1, axis=1)
        
        weighted_inputs = np.zeros(samples_count)

        for i in range(samples_count):
            weighted_inputs[i] = self.weighting(bias_added_inputs[i])

        activated_inputs = self.activation(weighted_inputs)

        for i in range(samples_count):
            if activated_inputs[i] >= 0:
                activated_inputs[i] = 1
            else:
                activated_inputs[i] = -1

        return activated_inputs

    def fit(self, inputs, outputs, learning_rate=0.1, epochs=64):
        bias_added_inputs = np.insert(inputs, 0, 1, axis=1)

        self.weights = np.random.rand(bias_added_inputs.shape[1])
        
        for i in range(epochs):
            od = self.predict(inputs)
            d_w = learning_rate * (outputs - od)
            d_w = d_w.reshape((d_w.shape[0], 1))
            d_w = np.tile(d_w, (1, bias_added_inputs.shape[1]))
            d_w = d_w * bias_added_inputs
            d_w = np.sum(d_w, axis=0)

            self.weights += d_w
            output_pred = self.predict(inputs)

            print(f'model accuracy after epoch{i+1}: {accuracy_score(outputs, output_pred)}')

# %% [markdown]
# <h4 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آموزش مدل
# </font>
# </h4>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
#     پس از طراحی ساختار پرسپترون می‌توانید به کمک <code dir=ltr>Adaline()</code> ابتدا یک نمونه از این کلاس بسازید و سپس تابع <code>fit</code> را با آرگومان‌های مناسب صدا بزنید تا آموزش مدل آغاز شود. این کار را برای هر سه حالت ورودی انجام دهید. پیشنهاد می‌شود مقادیر مختلف نرخ یادگیری مانند 0.1، 0.01، 0.001 و... را آزمایش و مقایسه کنید.
# </font>
# </p>

# %%
adaline = Adaline()
adaline.fit(x_df1.to_numpy(), y_df1.to_numpy(), 0.01)
# Out:
# model accuracy after epoch1: 0.5
# model accuracy after epoch2: 0.5
# model accuracy after epoch3: 0.5
# model accuracy after epoch4: 0.5
# model accuracy after epoch5: 0.5
# model accuracy after epoch6: 0.5
# model accuracy after epoch7: 0.53
# model accuracy after epoch8: 0.5
# model accuracy after epoch9: 1.0
# model accuracy after epoch10: 1.0
# model accuracy after epoch11: 1.0
# model accuracy after epoch12: 1.0
# model accuracy after epoch13: 1.0
# model accuracy after epoch14: 1.0
# model accuracy after epoch15: 1.0
# model accuracy after epoch16: 1.0
# model accuracy after epoch17: 1.0
# model accuracy after epoch18: 1.0
# model accuracy after epoch19: 1.0
# model accuracy after epoch20: 1.0
# model accuracy after epoch21: 1.0
# model accuracy after epoch22: 1.0
# model accuracy after epoch23: 1.0
# model accuracy after epoch24: 1.0
# model accuracy after epoch25: 1.0
# model accuracy after epoch26: 1.0
# model accuracy after epoch27: 1.0
# model accuracy after epoch28: 1.0
# model accuracy after epoch29: 1.0
# model accuracy after epoch30: 1.0
# model accuracy after epoch31: 1.0
# model accuracy after epoch32: 1.0
# model accuracy after epoch33: 1.0
# model accuracy after epoch34: 1.0
# model accuracy after epoch35: 1.0
# model accuracy after epoch36: 1.0
# model accuracy after epoch37: 1.0
# model accuracy after epoch38: 1.0
# model accuracy after epoch39: 1.0
# model accuracy after epoch40: 1.0
# model accuracy after epoch41: 1.0
# model accuracy after epoch42: 1.0
# model accuracy after epoch43: 1.0
# model accuracy after epoch44: 1.0
# model accuracy after epoch45: 1.0
# model accuracy after epoch46: 1.0
# model accuracy after epoch47: 1.0
# model accuracy after epoch48: 1.0
# model accuracy after epoch49: 1.0
# model accuracy after epoch50: 1.0
# model accuracy after epoch51: 1.0
# model accuracy after epoch52: 1.0
# model accuracy after epoch53: 1.0
# model accuracy after epoch54: 1.0
# model accuracy after epoch55: 1.0
# model accuracy after epoch56: 1.0
# model accuracy after epoch57: 1.0
# model accuracy after epoch58: 1.0
# model accuracy after epoch59: 1.0
# model accuracy after epoch60: 1.0
# model accuracy after epoch61: 1.0
# model accuracy after epoch62: 1.0
# model accuracy after epoch63: 1.0
# model accuracy after epoch64: 1.0

# %%
adaline = Adaline()
adaline.fit(x_df2.to_numpy(), y_df2.to_numpy(), 0.001)
# Out:
# model accuracy after epoch1: 0.0
# model accuracy after epoch2: 0.5
# model accuracy after epoch3: 0.5
# model accuracy after epoch4: 0.5
# model accuracy after epoch5: 1.0
# model accuracy after epoch6: 1.0
# model accuracy after epoch7: 1.0
# model accuracy after epoch8: 1.0
# model accuracy after epoch9: 1.0
# model accuracy after epoch10: 1.0
# model accuracy after epoch11: 1.0
# model accuracy after epoch12: 1.0
# model accuracy after epoch13: 1.0
# model accuracy after epoch14: 1.0
# model accuracy after epoch15: 1.0
# model accuracy after epoch16: 1.0
# model accuracy after epoch17: 1.0
# model accuracy after epoch18: 1.0
# model accuracy after epoch19: 1.0
# model accuracy after epoch20: 1.0
# model accuracy after epoch21: 1.0
# model accuracy after epoch22: 1.0
# model accuracy after epoch23: 1.0
# model accuracy after epoch24: 1.0
# model accuracy after epoch25: 1.0
# model accuracy after epoch26: 1.0
# model accuracy after epoch27: 1.0
# model accuracy after epoch28: 1.0
# model accuracy after epoch29: 1.0
# model accuracy after epoch30: 1.0
# model accuracy after epoch31: 1.0
# model accuracy after epoch32: 1.0
# model accuracy after epoch33: 1.0
# model accuracy after epoch34: 1.0
# model accuracy after epoch35: 1.0
# model accuracy after epoch36: 1.0
# model accuracy after epoch37: 1.0
# model accuracy after epoch38: 1.0
# model accuracy after epoch39: 1.0
# model accuracy after epoch40: 1.0
# model accuracy after epoch41: 1.0
# model accuracy after epoch42: 1.0
# model accuracy after epoch43: 1.0
# model accuracy after epoch44: 1.0
# model accuracy after epoch45: 1.0
# model accuracy after epoch46: 1.0
# model accuracy after epoch47: 1.0
# model accuracy after epoch48: 1.0
# model accuracy after epoch49: 1.0
# model accuracy after epoch50: 1.0
# model accuracy after epoch51: 1.0
# model accuracy after epoch52: 1.0
# model accuracy after epoch53: 1.0
# model accuracy after epoch54: 1.0
# model accuracy after epoch55: 1.0
# model accuracy after epoch56: 1.0
# model accuracy after epoch57: 1.0
# model accuracy after epoch58: 1.0
# model accuracy after epoch59: 1.0
# model accuracy after epoch60: 1.0
# model accuracy after epoch61: 1.0
# model accuracy after epoch62: 1.0
# model accuracy after epoch63: 1.0
# model accuracy after epoch64: 1.0

# %%
adaline = Adaline()
adaline.fit(x_df3.to_numpy(), y_df3.to_numpy(), 0.001)
# Out:
# model accuracy after epoch1: 0.5
# model accuracy after epoch2: 0.5
# model accuracy after epoch3: 0.5
# model accuracy after epoch4: 0.5
# model accuracy after epoch5: 0.5
# model accuracy after epoch6: 0.9
# model accuracy after epoch7: 0.54
# model accuracy after epoch8: 0.5
# model accuracy after epoch9: 0.93
# model accuracy after epoch10: 0.86
# model accuracy after epoch11: 0.5
# model accuracy after epoch12: 0.5
# model accuracy after epoch13: 0.65
# model accuracy after epoch14: 0.5
# model accuracy after epoch15: 0.5
# model accuracy after epoch16: 0.5
# model accuracy after epoch17: 0.71
# model accuracy after epoch18: 0.5
# model accuracy after epoch19: 0.5
# model accuracy after epoch20: 0.5
# model accuracy after epoch21: 0.5
# model accuracy after epoch22: 0.5
# model accuracy after epoch23: 0.93
# model accuracy after epoch24: 0.71
# model accuracy after epoch25: 0.5
# model accuracy after epoch26: 0.5
# model accuracy after epoch27: 0.5
# model accuracy after epoch28: 0.5
# model accuracy after epoch29: 0.58
# model accuracy after epoch30: 0.5
# model accuracy after epoch31: 0.58
# model accuracy after epoch32: 0.5
# model accuracy after epoch33: 0.6
# model accuracy after epoch34: 0.5
# model accuracy after epoch35: 0.52
# model accuracy after epoch36: 0.5
# model accuracy after epoch37: 0.85
# model accuracy after epoch38: 0.52
# model accuracy after epoch39: 0.5
# model accuracy after epoch40: 0.5
# model accuracy after epoch41: 0.5
# model accuracy after epoch42: 0.5
# model accuracy after epoch43: 0.5
# model accuracy after epoch44: 0.5
# model accuracy after epoch45: 0.56
# model accuracy after epoch46: 0.5
# model accuracy after epoch47: 0.66
# model accuracy after epoch48: 0.5
# model accuracy after epoch49: 0.5
# model accuracy after epoch50: 0.5
# model accuracy after epoch51: 0.65
# model accuracy after epoch52: 0.5
# model accuracy after epoch53: 0.5
# model accuracy after epoch54: 0.5
# model accuracy after epoch55: 0.69
# model accuracy after epoch56: 0.5
# model accuracy after epoch57: 0.5
# model accuracy after epoch58: 0.5
# model accuracy after epoch59: 0.55
# model accuracy after epoch60: 0.5
# model accuracy after epoch61: 0.68
# model accuracy after epoch62: 0.5
# model accuracy after epoch63: 0.5
# model accuracy after epoch64: 0.5

# %% [markdown]
# <h4 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# 💭
# تفکر
# </font>
# </h4>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
#     مقایسه‌ی عملکرد دو مدل <code>Perceptron</code> و <code>Adaline</code> در حالتی که مجموعه‌داده به شکل خطی تفکیک‌پذیر نباشد می‌تواند به شکل عملی تفاوت میان این دو مدل را برای‌تان شفاف سازد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>داوری</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در این تمرین هرکدام از توابعی که پیاده کرده‌اید به‌صورت جداگانه مورد داوری قرار خواهد گرفت تا از عملکرد هرکدام به شکل جداگانه مطمئن شوید. البته تابع <code>fit</code> هر کلاس به منزله‌ی عملکرد کلی مدل است و جهت ارزیابی، مدل شما بر روی یک حالت تفکیک‌پذیر خطی از مجموعه‌داده iris آموزش خواهد دید و انتظار می‌رود که بتواند دقت تقریبی ۱۰۰ درصد را بر روی مجموعه‌ی آموزشی به دست آورد. علاوه بر این دیتافریم‌های اولیه و پاسخ شما به پرسش مطرح‌شده درباره‌ی تفکیک‌پذیری خطی نیز امتیازدهی خواهد شد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     سلول‌های زیر را به منظور ساخت فایل‌های کلاس‌های پیاده‌سازی شده و پاسخ خود به پرسش مطرح شده اجرا نمایید.
# </font>
# </p>

# %%
with open("linearly_separable.json", "w") as f:
    json.dump(linearly_separable, f)
f.close()

# %%
inspect_perceptron = Perceptron()
with open("Perceptron.py", "w") as f:
    f.write('import numpy as np\n')
    f.write('from sklearn.metrics import accuracy_score\n')
    f.write('class Perceptron:\n')
    f.write(getsource(inspect_perceptron.__init__)+'\n')
    f.write(getsource(inspect_perceptron.weighting)+'\n')
    f.write(getsource(inspect_perceptron.activation)+'\n')
    f.write(getsource(inspect_perceptron.predict)+'\n')
    f.write(getsource(inspect_perceptron.fit)+'\n')
f.close()

# %%
inspect_adaline = Adaline()
with open("Adaline.py", "w") as f:
    f.write('import numpy as np\n')
    f.write('from sklearn.metrics import accuracy_score\n')
    f.write('class Adaline:\n')
    f.write(getsource(inspect_adaline.__init__)+'\n')
    f.write(getsource(inspect_adaline.weighting)+'\n')
    f.write(getsource(inspect_adaline.activation)+'\n')
    f.write(getsource(inspect_adaline.predict)+'\n')
    f.write(getsource(inspect_adaline.fit)+'\n')
f.close()

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

file_names = ['df1.csv', 'df2.csv', 'df3.csv', 'perceptron.ipynb', 'Perceptron.py', 'Adaline.py', 'linearly_separable.json']
compress(file_names)
# Out:
# File Paths:
# ['df1.csv', 'df2.csv', 'df3.csv', 'perceptron.ipynb', 'Perceptron.py', 'Adaline.py', 'linearly_separable.json']
